# %%
import numpy as np
import pandas as pd

region = pd.read_csv('159 indicators for all the countries 2000 to 2016.csv')

# %%
eap = region[(region['Country Name'] == 'China') | (region['Country Name'] == 'Japan') | 
               (region['Country Name'] == 'Vietnam') |  (region['Country Name'] == 'Korea, Dem. People\'s Rep.') | 
               (region['Country Name'] == 'Korea, Rep.') | (region['Country Name'] == 'Philippines') | 
               (region['Country Name'] == 'Australia') | (region['Country Name'] == 'New Zealand') | 
               (region['Country Name'] == 'Singapore')]
# region_countries = ['China', 'Japan', 'Vietnam', ]
eap.drop(columns = {'Unnamed: 0', 'Country Code', 'Indicator Code'}, inplace = True)
eap.sort_values(by = 'Country Name', inplace = True)
eap.set_index('Indicator Name', inplace = True)
eap
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# c:\python36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                    Country Name          2000  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...    Australia  9.560031e+01
# Employment in agriculture, male (% of male empl...    Australia  6.100000e+00
# School enrollment, tertiary, female (% gross)         Australia  7.395166e+01
# Employment in industry, female (% of female emp...    Australia  1.050000e+01
# School enrollment, tertiary (gross), gender par...    Australia  1.225420e+00
# Employment in industry, male (% of male employm...    Australia  3.060000e+01
# School enrollment, secondary, male (% net)            Australia           NaN
# Employment in services, female (% of female emp...    Australia  8.600000e+01
# School enrollment, secondary, male (% gross)          Australia  1.615886e+02
# Employment in services, male (% of male employm...    Australia  6.330000e+01
# School enrollment, secondary, female (% net)          Australia           NaN
# Employment to population ratio, 15+, female (%)...    Australia  5.150000e+01
# School enrollment, secondary, female (% gross)        Australia  1.636917e+02
# Employment to population ratio, 15+, female (%)...    Australia  5.120000e+01
# School enrollment, secondary (gross), gender pa...    Australia  1.013020e+00
# Employment to population ratio, 15+, male (%) (...    Australia  6.780000e+01
# School enrollment, primary, male (% net)              Australia  9.268170e+01
# Employment to population ratio, 15+, male (%) (...    Australia  6.740000e+01
# School enrollment, primary, male (% gross)            Australia  9.931445e+01
# Employment to population ratio, 15+, total (%) ...    Australia  5.920000e+01
# School enrollment, primary, female (% net)            Australia  9.550018e+01
# Employment to population ratio, ages 15-24, fem...    Australia  6.120000e+01
# School enrollment, primary, female (% gross)          Australia  1.014407e+02
# Employment to population ratio, ages 15-24, mal...    Australia  6.290000e+01
# School enrollment, primary and secondary (gross...    Australia  1.018830e+00
# Expected years of schooling, female                   Australia  2.096241e+01
# School enrollment, tertiary, male (% gross)           Australia  6.034798e+01
# Employment in agriculture, female (% of female ...    Australia  3.500000e+00
# Secondary education, pupils (% female)                Australia  4.889024e+01
# Employers, male (% of male employment) (modeled...    Australia  9.300000e+00
# ...                                                         ...           ...
# Prevalence of anemia among women of reproductiv...      Vietnam  2.790000e+01
# Urban population, male (% of total)                     Vietnam  1.194615e+01
# Immunization, measles (% of children ages 12-23...      Vietnam  9.700000e+01
# Pregnant women receiving prenatal care (%)              Vietnam  6.830000e+01
# Cause of death, by communicable diseases, ages ...      Vietnam  1.348822e+01
# Population, total                                       Vietnam  7.763090e+07
# Prevalence of overweight, female (% of female a...      Vietnam  1.220000e+01
# Cause of death, by non-communicable diseases, a...      Vietnam  7.952143e+01
# Cause of death, by injury, ages 35-59, female (...      Vietnam  8.612287e+00
# GNI per capita, PPP (current international $)           Vietnam  2.240000e+03
# Ratio of female to male labor force participati...      Vietnam  9.040736e+01
# Unemployment, female (% of female labor force) ...      Vietnam  2.100000e+00
# Ratio of female to male labor force participati...      Vietnam  8.907008e+01
# Cause of death, by non-communicable diseases, a...      Vietnam  2.478589e+01
# GDP (current US$)                                       Vietnam  3.117252e+10
# Proportion of women in ministerial level positi...      Vietnam           NaN
# GDP growth (annual %)                                   Vietnam  6.787316e+00
# Unemployment, male (% of male labor force) (mod...      Vietnam  2.400000e+00
# Primary education, pupils (% female)                    Vietnam  4.770818e+01
# Proportion of seats held by women in national p...      Vietnam  2.600000e+01
# GDP per capita (Current US$)                            Vietnam  4.015478e+02
# Unemployment, male (% of male labor force) (nat...      Vietnam  2.400000e+00
# Progression to secondary school, male (%)               Vietnam  9.442624e+01
# GNI per capita, Atlas method (current US$)              Vietnam  4.200000e+02
# Progression to secondary school, female (%)             Vietnam  9.233149e+01
# Cause of death, by injury, ages 35-59, male (% ...      Vietnam  1.936751e+01
# Primary education, teachers (% female)                  Vietnam  7.790366e+01
# Unemployment, youth female (% of female labor f...      Vietnam  4.400000e+00
# Cause of death, by non-communicable diseases, a...      Vietnam  3.752047e+01
# Age at first marriage, male                             Vietnam  2.600000e+01
#
#                                                             2001  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.559147e+01
# Employment in agriculture, male (% of male empl...  5.800000e+00
# School enrollment, tertiary, female (% gross)       7.396118e+01
# Employment in industry, female (% of female emp...  1.000000e+01
# School enrollment, tertiary (gross), gender par...  1.226570e+00
# Employment in industry, male (% of male employm...  2.960000e+01
# School enrollment, secondary, male (% net)                   NaN
# Employment in services, female (% of female emp...  8.660000e+01
# School enrollment, secondary, male (% gross)        1.553577e+02
# Employment in services, male (% of male employm...  6.460000e+01
# School enrollment, secondary, female (% net)                 NaN
# Employment to population ratio, 15+, female (%)...  5.170000e+01
# School enrollment, secondary, female (% gross)      1.545873e+02
# Employment to population ratio, 15+, female (%)...  5.150000e+01
# School enrollment, secondary (gross), gender pa...  9.950400e-01
# Employment to population ratio, 15+, male (%) (...  6.710000e+01
# School enrollment, primary, male (% net)            9.244963e+01
# Employment to population ratio, 15+, male (%) (...  6.680000e+01
# School enrollment, primary, male (% gross)          9.913593e+01
# Employment to population ratio, 15+, total (%) ...  5.900000e+01
# School enrollment, primary, female (% net)          9.547837e+01
# Employment to population ratio, ages 15-24, fem...  6.060000e+01
# School enrollment, primary, female (% gross)        1.014577e+02
# Employment to population ratio, ages 15-24, mal...  6.160000e+01
# School enrollment, primary and secondary (gross...  1.009230e+00
# Expected years of schooling, female                 2.048785e+01
# School enrollment, tertiary, male (% gross)         6.029923e+01
# Employment in agriculture, female (% of female ...  3.500000e+00
# Secondary education, pupils (% female)              4.839031e+01
# Employers, male (% of male employment) (modeled...  9.500000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.670000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.800000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   7.862050e+07
# Prevalence of overweight, female (% of female a...  1.260000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       2.400000e+03
# Ratio of female to male labor force participati...  9.062499e+01
# Unemployment, female (% of female labor force) ...  3.300000e+00
# Ratio of female to male labor force participati...  8.907159e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   3.268520e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               6.192893e+00
# Unemployment, male (% of male labor force) (mod...  2.300000e+00
# Primary education, pupils (% female)                4.765362e+01
# Proportion of seats held by women in national p...  2.600000e+01
# GDP per capita (Current US$)                        4.157338e+02
# Unemployment, male (% of male labor force) (nat...  2.300000e+00
# Progression to secondary school, male (%)           9.500521e+01
# GNI per capita, Atlas method (current US$)          4.400000e+02
# Progression to secondary school, female (%)         9.457438e+01
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.830769e+01
# Unemployment, youth female (% of female labor f...  7.000000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2002  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.562742e+01
# Employment in agriculture, male (% of male empl...  5.400000e+00
# School enrollment, tertiary, female (% gross)       8.350060e+01
# Employment in industry, female (% of female emp...  1.000000e+01
# School enrollment, tertiary (gross), gender par...  1.222330e+00
# Employment in industry, male (% of male employm...  2.980000e+01
# School enrollment, secondary, male (% net)          8.686818e+01
# Employment in services, female (% of female emp...  8.690000e+01
# School enrollment, secondary, male (% gross)        1.556652e+02
# Employment in services, male (% of male employm...  6.470000e+01
# School enrollment, secondary, female (% net)        8.990237e+01
# Employment to population ratio, 15+, female (%)...  5.200000e+01
# School enrollment, secondary, female (% gross)      1.528723e+02
# Employment to population ratio, 15+, female (%)...  5.180000e+01
# School enrollment, secondary (gross), gender pa...  9.820600e-01
# Employment to population ratio, 15+, male (%) (...  6.730000e+01
# School enrollment, primary, male (% net)            9.250086e+01
# Employment to population ratio, 15+, male (%) (...  6.710000e+01
# School enrollment, primary, male (% gross)          1.000762e+02
# Employment to population ratio, 15+, total (%) ...  5.930000e+01
# School enrollment, primary, female (% net)          9.543001e+01
# Employment to population ratio, ages 15-24, fem...  6.020000e+01
# School enrollment, primary, female (% gross)        1.023112e+02
# Employment to population ratio, ages 15-24, mal...  6.160000e+01
# School enrollment, primary and secondary (gross...  1.001080e+00
# Expected years of schooling, female                 2.079991e+01
# School enrollment, tertiary, male (% gross)         6.831263e+01
# Employment in agriculture, female (% of female ...  3.100000e+00
# Secondary education, pupils (% female)              4.800984e+01
# Employers, male (% of male employment) (modeled...  9.300000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.580000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.600000e+01
# Pregnant women receiving prenatal care (%)          8.640000e+01
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   7.953770e+07
# Prevalence of overweight, female (% of female a...  1.300000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       2.560000e+03
# Ratio of female to male labor force participati...  9.055118e+01
# Unemployment, female (% of female labor force) ...  2.300000e+00
# Ratio of female to male labor force participati...  8.906839e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   3.506411e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               6.320821e+00
# Unemployment, male (% of male labor force) (mod...  1.900000e+00
# Primary education, pupils (% female)                4.751649e+01
# Proportion of seats held by women in national p...  2.730000e+01
# GDP per capita (Current US$)                        4.408489e+02
# Unemployment, male (% of male labor force) (nat...  1.900000e+00
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          4.600000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.783258e+01
# Unemployment, youth female (% of female labor f...  4.400000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                         2.610000e+01
#
#                                                             2003  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.615972e+01
# Employment in agriculture, male (% of male empl...  4.900000e+00
# School enrollment, tertiary, female (% gross)       8.126753e+01
# Employment in industry, female (% of female emp...  1.000000e+01
# School enrollment, tertiary (gross), gender par...  1.233900e+00
# Employment in industry, male (% of male employm...  2.990000e+01
# School enrollment, secondary, male (% net)          8.537284e+01
# Employment in services, female (% of female emp...  8.740000e+01
# School enrollment, secondary, male (% gross)        1.570852e+02
# Employment in services, male (% of male employm...  6.520000e+01
# School enrollment, secondary, female (% net)        8.799625e+01
# Employment to population ratio, 15+, female (%)...  5.270000e+01
# School enrollment, secondary, female (% gross)      1.552445e+02
# Employment to population ratio, 15+, female (%)...  5.260000e+01
# School enrollment, secondary (gross), gender pa...  9.882800e-01
# Employment to population ratio, 15+, male (%) (...  6.750000e+01
# School enrollment, primary, male (% net)            9.309713e+01
# Employment to population ratio, 15+, male (%) (...  6.730000e+01
# School enrollment, primary, male (% gross)          1.002290e+02
# Employment to population ratio, 15+, total (%) ...  5.980000e+01
# School enrollment, primary, female (% net)          9.597339e+01
# Employment to population ratio, ages 15-24, fem...  6.120000e+01
# School enrollment, primary, female (% gross)        1.024043e+02
# Employment to population ratio, ages 15-24, mal...  6.220000e+01
# School enrollment, primary and secondary (gross...  1.003850e+00
# Expected years of schooling, female                 2.097711e+01
# School enrollment, tertiary, male (% gross)         6.586240e+01
# Employment in agriculture, female (% of female ...  2.600000e+00
# Secondary education, pupils (% female)              4.810317e+01
# Employers, male (% of male employment) (modeled...  9.100000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.500000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.300000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.046740e+07
# Prevalence of overweight, female (% of female a...  1.350000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       2.760000e+03
# Ratio of female to male labor force participati...  9.036939e+01
# Unemployment, female (% of female labor force) ...  2.600000e+00
# Ratio of female to male labor force participati...  8.906069e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   3.955251e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               6.899063e+00
# Unemployment, male (% of male labor force) (mod...  2.000000e+00
# Primary education, pupils (% female)                4.749267e+01
# Proportion of seats held by women in national p...  2.730000e+01
# GDP per capita (Current US$)                        4.915346e+02
# Unemployment, male (% of male labor force) (nat...  1.900000e+00
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          5.100000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.796830e+01
# Unemployment, youth female (% of female labor f...  5.000000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2004  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.642868e+01
# Employment in agriculture, male (% of male empl...  4.500000e+00
# School enrollment, tertiary, female (% gross)       7.958493e+01
# Employment in industry, female (% of female emp...  9.700000e+00
# School enrollment, tertiary (gross), gender par...  1.240020e+00
# Employment in industry, male (% of male employm...  3.070000e+01
# School enrollment, secondary, male (% net)          8.491983e+01
# Employment in services, female (% of female emp...  8.760000e+01
# School enrollment, secondary, male (% gross)        1.515496e+02
# Employment in services, male (% of male employm...  6.480000e+01
# School enrollment, secondary, female (% net)        8.775382e+01
# Employment to population ratio, 15+, female (%)...  5.270000e+01
# School enrollment, secondary, female (% gross)      1.482220e+02
# Employment to population ratio, 15+, female (%)...  5.260000e+01
# School enrollment, secondary (gross), gender pa...  9.780400e-01
# Employment to population ratio, 15+, male (%) (...  6.790000e+01
# School enrollment, primary, male (% net)            9.357444e+01
# Employment to population ratio, 15+, male (%) (...  6.770000e+01
# School enrollment, primary, male (% gross)          1.009448e+02
# Employment to population ratio, 15+, total (%) ...  6.000000e+01
# School enrollment, primary, female (% net)          9.625934e+01
# Employment to population ratio, ages 15-24, fem...  6.160000e+01
# School enrollment, primary, female (% gross)        1.028855e+02
# Employment to population ratio, ages 15-24, mal...  6.270000e+01
# School enrollment, primary and secondary (gross...  9.964800e-01
# Expected years of schooling, female                 2.058866e+01
# School enrollment, tertiary, male (% gross)         6.418039e+01
# Employment in agriculture, female (% of female ...  2.700000e+00
# Secondary education, pupils (% female)              4.775589e+01
# Employers, male (% of male employment) (modeled...  9.100000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.420000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.700000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.143640e+07
# Prevalence of overweight, female (% of female a...  1.390000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       3.020000e+03
# Ratio of female to male labor force participati...  8.953642e+01
# Unemployment, female (% of female labor force) ...  2.400000e+00
# Ratio of female to male labor force participati...  8.904697e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   4.542785e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               7.536411e+00
# Unemployment, male (% of male labor force) (mod...  1.800000e+00
# Primary education, pupils (% female)                4.732154e+01
# Proportion of seats held by women in national p...  2.730000e+01
# GDP per capita (Current US$)                        5.578323e+02
# Unemployment, male (% of male labor force) (nat...  1.900000e+00
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          5.900000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.832842e+01
# Unemployment, youth female (% of female labor f...  4.700000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2005  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.676741e+01
# Employment in agriculture, male (% of male empl...  4.400000e+00
# School enrollment, tertiary, female (% gross)       8.080501e+01
# Employment in industry, female (% of female emp...  9.800000e+00
# School enrollment, tertiary (gross), gender par...  1.258620e+00
# Employment in industry, male (% of male employm...  3.080000e+01
# School enrollment, secondary, male (% net)          8.304458e+01
# Employment in services, female (% of female emp...  8.780000e+01
# School enrollment, secondary, male (% gross)        1.501054e+02
# Employment in services, male (% of male employm...  6.490000e+01
# School enrollment, secondary, female (% net)        8.702086e+01
# Employment to population ratio, 15+, female (%)...  5.410000e+01
# School enrollment, secondary, female (% gross)      1.464968e+02
# Employment to population ratio, 15+, female (%)...  5.400000e+01
# School enrollment, secondary (gross), gender pa...  9.759600e-01
# Employment to population ratio, 15+, male (%) (...  6.870000e+01
# School enrollment, primary, male (% net)            9.415555e+01
# Employment to population ratio, 15+, male (%) (...  6.860000e+01
# School enrollment, primary, male (% gross)          1.016460e+02
# Employment to population ratio, 15+, total (%) ...  6.120000e+01
# School enrollment, primary, female (% net)          9.657359e+01
# Employment to population ratio, ages 15-24, fem...  6.230000e+01
# School enrollment, primary, female (% gross)        1.031873e+02
# Employment to population ratio, ages 15-24, mal...  6.420000e+01
# School enrollment, primary and secondary (gross...  9.928300e-01
# Expected years of schooling, female                 2.056945e+01
# School enrollment, tertiary, male (% gross)         6.420102e+01
# Employment in agriculture, female (% of female ...  2.400000e+00
# Secondary education, pupils (% female)              4.759181e+01
# Employers, male (% of male employment) (modeled...  9.200000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.340000e+01
# Urban population, male (% of total)                 1.334699e+01
# Immunization, measles (% of children ages 12-23...  9.500000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...  1.376766e+01
# Population, total                                   8.239210e+07
# Prevalence of overweight, female (% of female a...  1.440000e+01
# Cause of death, by non-communicable diseases, a...  8.142583e+01
# Cause of death, by injury, ages 35-59, female (...  8.071504e+00
# GNI per capita, PPP (current international $)       3.050000e+03
# Ratio of female to male labor force participati...           NaN
# Unemployment, female (% of female labor force) ...           NaN
# Ratio of female to male labor force participati...  8.902344e+01
# Cause of death, by non-communicable diseases, a...  2.292292e+01
# GDP (current US$)                                   5.763326e+10
# Proportion of women in ministerial level positi...  1.150000e+01
# GDP growth (annual %)                               7.547248e+00
# Unemployment, male (% of male labor force) (mod...  2.400000e+00
# Primary education, pupils (% female)                4.747631e+01
# Proportion of seats held by women in national p...  2.730000e+01
# GDP per capita (Current US$)                        6.994998e+02
# Unemployment, male (% of male labor force) (nat...           NaN
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          6.400000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...  1.819467e+01
# Primary education, teachers (% female)              7.802975e+01
# Unemployment, youth female (% of female labor f...  5.700000e+00
# Cause of death, by non-communicable diseases, a...  3.552612e+01
# Age at first marriage, male                         2.600000e+01
#
#                                                             2006  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.695121e+01
# Employment in agriculture, male (% of male empl...  4.300000e+00
# School enrollment, tertiary, female (% gross)       8.067346e+01
# Employment in industry, female (% of female emp...  9.400000e+00
# School enrollment, tertiary (gross), gender par...  1.284880e+00
# Employment in industry, male (% of male employm...  3.100000e+01
# School enrollment, secondary, male (% net)          8.239372e+01
# Employment in services, female (% of female emp...  8.830000e+01
# School enrollment, secondary, male (% gross)        1.274698e+02
# Employment in services, male (% of male employm...  6.470000e+01
# School enrollment, secondary, female (% net)        8.651075e+01
# Employment to population ratio, 15+, female (%)...  5.480000e+01
# School enrollment, secondary, female (% gross)      1.273031e+02
# Employment to population ratio, 15+, female (%)...  5.470000e+01
# School enrollment, secondary (gross), gender pa...  9.986900e-01
# Employment to population ratio, 15+, male (%) (...  6.890000e+01
# School enrollment, primary, male (% net)            9.463645e+01
# Employment to population ratio, 15+, male (%) (...  6.890000e+01
# School enrollment, primary, male (% gross)          1.024216e+02
# Employment to population ratio, 15+, total (%) ...  6.170000e+01
# School enrollment, primary, female (% net)          9.679291e+01
# Employment to population ratio, ages 15-24, fem...  6.290000e+01
# School enrollment, primary, female (% gross)        1.036415e+02
# Employment to population ratio, ages 15-24, mal...  6.450000e+01
# School enrollment, primary and secondary (gross...  1.004420e+00
# Expected years of schooling, female                 1.943916e+01
# School enrollment, tertiary, male (% gross)         6.278658e+01
# Employment in agriculture, female (% of female ...  2.300000e+00
# Secondary education, pupils (% female)              4.806200e+01
# Employers, male (% of male employment) (modeled...  8.900000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.270000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.300000e+01
# Pregnant women receiving prenatal care (%)          9.080000e+01
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.331120e+07
# Prevalence of overweight, female (% of female a...  1.490000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       3.310000e+03
# Ratio of female to male labor force participati...           NaN
# Unemployment, female (% of female labor force) ...           NaN
# Ratio of female to male labor force participati...  8.901786e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   6.637166e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               6.977955e+00
# Unemployment, male (% of male labor force) (mod...  2.400000e+00
# Primary education, pupils (% female)                4.790538e+01
# Proportion of seats held by women in national p...  2.730000e+01
# GDP per capita (Current US$)                        7.966716e+02
# Unemployment, male (% of male labor force) (nat...           NaN
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          7.300000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.810824e+01
# Unemployment, youth female (% of female labor f...  5.200000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2007  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.755316e+01
# Employment in agriculture, male (% of male empl...  4.200000e+00
# School enrollment, tertiary, female (% gross)       8.239168e+01
# Employment in industry, female (% of female emp...  9.400000e+00
# School enrollment, tertiary (gross), gender par...  1.302910e+00
# Employment in industry, male (% of male employm...  3.100000e+01
# School enrollment, secondary, male (% net)          8.247627e+01
# Employment in services, female (% of female emp...  8.840000e+01
# School enrollment, secondary, male (% gross)        1.259996e+02
# Employment in services, male (% of male employm...  6.480000e+01
# School enrollment, secondary, female (% net)        8.656282e+01
# Employment to population ratio, 15+, female (%)...  5.550000e+01
# School enrollment, secondary, female (% gross)      1.267630e+02
# Employment to population ratio, 15+, female (%)...  5.530000e+01
# School enrollment, secondary (gross), gender pa...  1.006060e+00
# Employment to population ratio, 15+, male (%) (...  6.970000e+01
# School enrollment, primary, male (% net)            9.558535e+01
# Employment to population ratio, 15+, male (%) (...  6.960000e+01
# School enrollment, primary, male (% gross)          1.045762e+02
# Employment to population ratio, 15+, total (%) ...  6.230000e+01
# School enrollment, primary, female (% net)          9.739647e+01
# Employment to population ratio, ages 15-24, fem...  6.330000e+01
# School enrollment, primary, female (% gross)        1.054206e+02
# Employment to population ratio, ages 15-24, mal...  6.500000e+01
# School enrollment, primary and secondary (gross...  1.006350e+00
# Expected years of schooling, female                 1.960524e+01
# School enrollment, tertiary, male (% gross)         6.323678e+01
# Employment in agriculture, female (% of female ...  2.200000e+00
# Secondary education, pupils (% female)              4.819389e+01
# Employers, male (% of male employment) (modeled...  8.300000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.200000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  8.300000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.421850e+07
# Prevalence of overweight, female (% of female a...  1.540000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       3.580000e+03
# Ratio of female to male labor force participati...  8.997462e+01
# Unemployment, female (% of female labor force) ...           NaN
# Ratio of female to male labor force participati...  8.900849e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   7.741443e+10
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               7.129504e+00
# Unemployment, male (% of male labor force) (mod...  2.500000e+00
# Primary education, pupils (% female)                4.780038e+01
# Proportion of seats held by women in national p...  2.580000e+01
# GDP per capita (Current US$)                        9.192093e+02
# Unemployment, male (% of male labor force) (nat...           NaN
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          8.500000e+02
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.766255e+01
# Unemployment, youth female (% of female labor f...  6.800000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                         2.660000e+01
#
#                                                             2008  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.759558e+01
# Employment in agriculture, male (% of male empl...  4.200000e+00
# School enrollment, tertiary, female (% gross)       8.350862e+01
# Employment in industry, female (% of female emp...  9.400000e+00
# School enrollment, tertiary (gross), gender par...  1.324950e+00
# Employment in industry, male (% of male employm...  3.160000e+01
# School enrollment, secondary, male (% net)          8.282598e+01
# Employment in services, female (% of female emp...  8.850000e+01
# School enrollment, secondary, male (% gross)        1.280495e+02
# Employment in services, male (% of male employm...  6.420000e+01
# School enrollment, secondary, female (% net)        8.697543e+01
# Employment to population ratio, 15+, female (%)...  5.600000e+01
# School enrollment, secondary, female (% gross)      1.280174e+02
# Employment to population ratio, 15+, female (%)...  5.590000e+01
# School enrollment, secondary (gross), gender pa...  9.997500e-01
# Employment to population ratio, 15+, male (%) (...  6.980000e+01
# School enrollment, primary, male (% net)            9.577257e+01
# Employment to population ratio, 15+, male (%) (...  6.980000e+01
# School enrollment, primary, male (% gross)          1.047749e+02
# Employment to population ratio, 15+, total (%) ...  6.270000e+01
# School enrollment, primary, female (% net)          9.744056e+01
# Employment to population ratio, ages 15-24, fem...  6.360000e+01
# School enrollment, primary, female (% gross)        1.053591e+02
# Employment to population ratio, ages 15-24, mal...  6.550000e+01
# School enrollment, primary and secondary (gross...  1.001620e+00
# Expected years of schooling, female                 1.965924e+01
# School enrollment, tertiary, male (% gross)         6.302780e+01
# Employment in agriculture, female (% of female ...  2.200000e+00
# Secondary education, pupils (% female)              4.803086e+01
# Employers, male (% of male employment) (modeled...  8.400000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.130000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.200000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.511870e+07
# Prevalence of overweight, female (% of female a...  1.590000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       3.810000e+03
# Ratio of female to male labor force participati...           NaN
# Unemployment, female (% of female labor force) ...           NaN
# Ratio of female to male labor force participati...  8.898375e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   9.913030e+10
# Proportion of women in ministerial level positi...  4.200000e+00
# GDP growth (annual %)                               5.661771e+00
# Unemployment, male (% of male labor force) (mod...  2.300000e+00
# Primary education, pupils (% female)                         NaN
# Proportion of seats held by women in national p...  2.580000e+01
# GDP per capita (Current US$)                        1.164613e+03
# Unemployment, male (% of male labor force) (nat...           NaN
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          1.000000e+03
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.733034e+01
# Unemployment, youth female (% of female labor f...  5.900000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2009  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.751381e+01
# Employment in agriculture, male (% of male empl...  4.200000e+00
# School enrollment, tertiary, female (% gross)       8.893452e+01
# Employment in industry, female (% of female emp...  9.200000e+00
# School enrollment, tertiary (gross), gender par...  1.358450e+00
# Employment in industry, male (% of male employm...  3.100000e+01
# School enrollment, secondary, male (% net)          8.429225e+01
# Employment in services, female (% of female emp...  8.860000e+01
# School enrollment, secondary, male (% gross)        1.314839e+02
# Employment in services, male (% of male employm...  6.480000e+01
# School enrollment, secondary, female (% net)        8.779325e+01
# Employment to population ratio, 15+, female (%)...  5.560000e+01
# School enrollment, secondary, female (% gross)      1.290596e+02
# Employment to population ratio, 15+, female (%)...  5.560000e+01
# School enrollment, secondary (gross), gender pa...  9.815600e-01
# Employment to population ratio, 15+, male (%) (...  6.820000e+01
# School enrollment, primary, male (% net)            9.608851e+01
# Employment to population ratio, 15+, male (%) (...  6.820000e+01
# School enrollment, primary, male (% gross)          1.052284e+02
# Employment to population ratio, 15+, total (%) ...  6.180000e+01
# School enrollment, primary, female (% net)          9.736515e+01
# Employment to population ratio, ages 15-24, fem...  6.070000e+01
# School enrollment, primary, female (% gross)        1.054151e+02
# Employment to population ratio, ages 15-24, mal...  6.180000e+01
# School enrollment, primary and secondary (gross...  9.899700e-01
# Expected years of schooling, female                 1.998643e+01
# School enrollment, tertiary, male (% gross)         6.546756e+01
# Employment in agriculture, female (% of female ...  2.300000e+00
# Secondary education, pupils (% female)              4.760596e+01
# Employers, male (% of male employment) (modeled...  8.600000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.090000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.700000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   8.602500e+07
# Prevalence of overweight, female (% of female a...  1.640000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       3.950000e+03
# Ratio of female to male labor force participati...  8.925926e+01
# Unemployment, female (% of female labor force) ...  2.700000e+00
# Ratio of female to male labor force participati...  8.894259e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   1.060147e+11
# Proportion of women in ministerial level positi...           NaN
# GDP growth (annual %)                               5.397898e+00
# Unemployment, male (% of male labor force) (mod...  2.500000e+00
# Primary education, pupils (% female)                4.793241e+01
# Proportion of seats held by women in national p...  2.580000e+01
# GDP per capita (Current US$)                        1.232370e+03
# Unemployment, male (% of male labor force) (nat...  2.500000e+00
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          1.120000e+03
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.796645e+01
# Unemployment, youth female (% of female labor f...  5.800000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                         2.620000e+01
#
#                                                             2010  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.762961e+01
# Employment in agriculture, male (% of male empl...  4.100000e+00
# School enrollment, tertiary, female (% gross)       9.445540e+01
# Employment in industry, female (% of female emp...  8.900000e+00
# School enrollment, tertiary (gross), gender par...  1.380990e+00
# Employment in industry, male (% of male employm...  3.080000e+01
# School enrollment, secondary, male (% net)          8.470200e+01
# Employment in services, female (% of female emp...  8.880000e+01
# School enrollment, secondary, male (% gross)        1.344217e+02
# Employment in services, male (% of male employm...  6.510000e+01
# School enrollment, secondary, female (% net)        8.788129e+01
# Employment to population ratio, 15+, female (%)...  5.560000e+01
# School enrollment, secondary, female (% gross)      1.303395e+02
# Employment to population ratio, 15+, female (%)...  5.550000e+01
# School enrollment, secondary (gross), gender pa...  9.696300e-01
# Employment to population ratio, 15+, male (%) (...  6.880000e+01
# School enrollment, primary, male (% net)            9.650969e+01
# Employment to population ratio, 15+, male (%) (...  6.870000e+01
# School enrollment, primary, male (% gross)          1.057965e+02
# Employment to population ratio, 15+, total (%) ...  6.200000e+01
# School enrollment, primary, female (% net)          9.749754e+01
# Employment to population ratio, ages 15-24, fem...  5.980000e+01
# School enrollment, primary, female (% gross)        1.056065e+02
# Employment to population ratio, ages 15-24, mal...  6.150000e+01
# School enrollment, primary and secondary (gross...  9.818200e-01
# Expected years of schooling, female                 2.032130e+01
# School enrollment, tertiary, male (% gross)         6.839690e+01
# Employment in agriculture, female (% of female ...  2.300000e+00
# Secondary education, pupils (% female)              4.736659e+01
# Employers, male (% of male employment) (modeled...  8.600000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.060000e+01
# Urban population, male (% of total)                 1.467203e+01
# Immunization, measles (% of children ages 12-23...  9.800000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...  1.190091e+01
# Population, total                                   8.693250e+07
# Prevalence of overweight, female (% of female a...  1.700000e+01
# Cause of death, by non-communicable diseases, a...  8.229631e+01
# Cause of death, by injury, ages 35-59, female (...  8.215410e+00
# GNI per capita, PPP (current international $)       4.230000e+03
# Ratio of female to male labor force participati...  8.902439e+01
# Unemployment, female (% of female labor force) ...  3.000000e+00
# Ratio of female to male labor force participati...  8.881521e+01
# Cause of death, by non-communicable diseases, a...  2.378027e+01
# GDP (current US$)                                   1.159317e+11
# Proportion of women in ministerial level positi...  4.200000e+00
# GDP growth (annual %)                               6.423238e+00
# Unemployment, male (% of male labor force) (mod...  2.500000e+00
# Primary education, pupils (% female)                4.726326e+01
# Proportion of seats held by women in national p...  2.580000e+01
# GDP per capita (Current US$)                        1.333584e+03
# Unemployment, male (% of male labor force) (nat...  2.300000e+00
# ...
# Prevalence of anemia among women of reproductiv...  2.220000e+01
# Urban population, male (% of total)                          NaN
# Immunization, measles (% of children ages 12-23...  9.700000e+01
# Pregnant women receiving prenatal care (%)          9.580000e+01
# Cause of death, by communicable diseases, ages ...           NaN
# Population, total                                   9.072890e+07
# Prevalence of overweight, female (% of female a...  1.930000e+01
# Cause of death, by non-communicable diseases, a...           NaN
# Cause of death, by injury, ages 35-59, female (...           NaN
# GNI per capita, PPP (current international $)       5.390000e+03
# Ratio of female to male labor force participati...  8.884849e+01
# Unemployment, female (% of female labor force) ...  1.800000e+00
# Ratio of female to male labor force participati...  8.854035e+01
# Cause of death, by non-communicable diseases, a...           NaN
# GDP (current US$)                                   1.862047e+11
# Proportion of women in ministerial level positi...  9.100000e+00
# GDP growth (annual %)                               5.983655e+00
# Unemployment, male (% of male labor force) (mod...  1.900000e+00
# Primary education, pupils (% female)                4.792565e+01
# Proportion of seats held by women in national p...  2.430000e+01
# GDP per capita (Current US$)                        2.052319e+03
# Unemployment, male (% of male labor force) (nat...  1.900000e+00
# Progression to secondary school, male (%)           9.663398e+01
# GNI per capita, Atlas method (current US$)          1.900000e+03
# Progression to secondary school, female (%)         9.113253e+01
# Cause of death, by injury, ages 35-59, male (% ...           NaN
# Primary education, teachers (% female)              7.482123e+01
# Unemployment, youth female (% of female labor f...  6.500000e+00
# Cause of death, by non-communicable diseases, a...           NaN
# Age at first marriage, male                                  NaN
#
#                                                             2015  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...  9.748090e+01
# Employment in agriculture, male (% of male empl...  3.700000e+00
# School enrollment, tertiary, female (% gross)                NaN
# Employment in industry, female (% of female emp...  8.600000e+00
# School enrollment, tertiary (gross), gender par...           NaN
# Employment in industry, male (% of male employm...  3.280000e+01
# School enrollment, secondary, male (% net)                   NaN
# Employment in services, female (% of female emp...  8.970000e+01
# School enrollment, secondary, male (% gross)                 NaN
# Employment in services, male (% of male employm...  6.350000e+01
# School enrollment, secondary, female (% net)                 NaN
# Employment to population ratio, 15+, female (%)...  5.500000e+01
# School enrollment, secondary, female (% gross)               NaN
# Employment to population ratio, 15+, female (%)...  5.540000e+01
# School enrollment, secondary (gross), gender pa...           NaN
# Employment to population ratio, 15+, male (%) (...  6.660000e+01
# School enrollment, primary, male (% net)            9.674724e+01
# Employment to population ratio, 15+, male (%) (...  6.680000e+01
# School enrollment, primary, male (% gross)          1.023158e+02
# Employment to population ratio, 15+, total (%) ...  6.100000e+01
# School enrollment, primary, female (% net)          9.733416e+01
# Employment to population ratio, ages 15-24, fem...  5.790000e+01
# School enrollment, primary, female (% gross)        1.020939e+02
# Employment to population ratio, ages 15-24, mal...  5.750000e+01
# School enrollment, primary and secondary (gross...           NaN
# Expected years of schooling, female                          NaN
# School enrollment, tertiary, male (% gross)                  NaN
# Employment in agriculture, female (% of female ...  1.700000e+00
# Secondary education, pupils (% female)                       NaN
# Employers, male (% of male employment) (modeled...  7.800000e+00
# ...                                                          ...
# Prevalence of anemia among women of reproductiv...  2.310000e+01
# Urban population, male (% of total)                 1.625297e+01
# Immunization, measles (% of children ages 12-23...  9.700000e+01
# Pregnant women receiving prenatal care (%)                   NaN
# Cause of death, by communicable diseases, ages ...  1.179884e+01
# Population, total                                   9.171330e+07
# Prevalence of overweight, female (% of female a...  1.990000e+01
# Cause of death, by non-communicable diseases, a...  8.237028e+01
# Cause of death, by injury, ages 35-59, female (...  8.672497e+00
# GNI per capita, PPP (current international $)       5.740000e+03
# Ratio of female to male labor force participati...  8.822815e+01
# Unemployment, female (% of female labor force) ...  2.000000e+00
# Ratio of female to male labor force participati...  8.745494e+01
# Cause of death, by non-communicable diseases, a...  2.486056e+01
# GDP (current US$)                                   1.932411e+11
# Proportion of women in ministerial level positi...  9.100000e+00
# GDP growth (annual %)                               6.679289e+00
# Unemployment, male (% of male labor force) (mod...  2.200000e+00
# Primary education, pupils (% female)                4.787020e+01
# Proportion of seats held by women in national p...  2.430000e+01
# GDP per capita (Current US$)                        2.107013e+03
# Unemployment, male (% of male labor force) (nat...  2.200000e+00
# Progression to secondary school, male (%)                    NaN
# GNI per capita, Atlas method (current US$)          1.990000e+03
# Progression to secondary school, female (%)                  NaN
# Cause of death, by injury, ages 35-59, male (% ...  1.673064e+01
# Primary education, teachers (% female)              7.762383e+01
# Unemployment, youth female (% of female labor f...  6.900000e+00
# Cause of death, by non-communicable diseases, a...  3.857146e+01
# Age at first marriage, male                                  NaN
#
#                                                             2016       2017  \
# Indicator Name
# Adjusted net enrollment rate, primary, female (...           NaN        NaN
# Employment in agriculture, male (% of male empl...  3.600000e+00   3.600000
# School enrollment, tertiary, female (% gross)                NaN        NaN
# Employment in industry, female (% of female emp...  8.300000e+00   8.200000
# School enrollment, tertiary (gross), gender par...           NaN        NaN
# Employment in industry, male (% of male employm...  3.230000e+01  32.000000
# School enrollment, secondary, male (% net)                   NaN        NaN
# Employment in services, female (% of female emp...  9.000000e+01  90.199997
# School enrollment, secondary, male (% gross)                 NaN        NaN
# Employment in services, male (% of male employm...  6.400000e+01  64.400002
# School enrollment, secondary, female (% net)                 NaN        NaN
# Employment to population ratio, 15+, female (%)...  5.510000e+01  55.000000
# School enrollment, secondary, female (% gross)               NaN        NaN
# Employment to population ratio, 15+, female (%)...  5.580000e+01        NaN
# School enrollment, secondary (gross), gender pa...           NaN        NaN
# Employment to population ratio, 15+, male (%) (...  6.680000e+01  66.699997
# School enrollment, primary, male (% net)                     NaN        NaN
# Employment to population ratio, 15+, male (%) (...  6.660000e+01        NaN
# School enrollment, primary, male (% gross)                   NaN        NaN
# Employment to population ratio, 15+, total (%) ...  6.110000e+01        NaN
# School enrollment, primary, female (% net)                   NaN        NaN
# Employment to population ratio, ages 15-24, fem...  5.830000e+01  58.299999
# School enrollment, primary, female (% gross)                 NaN        NaN
# Employment to population ratio, ages 15-24, mal...  5.780000e+01  58.000000
# School enrollment, primary and secondary (gross...           NaN        NaN
# Expected years of schooling, female                          NaN        NaN
# School enrollment, tertiary, male (% gross)                  NaN        NaN
# Employment in agriculture, female (% of female ...  1.700000e+00   1.700000
# Secondary education, pupils (% female)                       NaN        NaN
# Employers, male (% of male employment) (modeled...  7.900000e+00   7.800000
# ...                                                          ...        ...
# Prevalence of anemia among women of reproductiv...  2.420000e+01        NaN
# Urban population, male (% of total)                          NaN        NaN
# Immunization, measles (% of children ages 12-23...  9.900000e+01        NaN
# Pregnant women receiving prenatal care (%)                   NaN        NaN
# Cause of death, by communicable diseases, ages ...           NaN        NaN
# Population, total                                   9.270110e+07        NaN
# Prevalence of overweight, female (% of female a...  2.050000e+01        NaN
# Cause of death, by non-communicable diseases, a...           NaN        NaN
# Cause of death, by injury, ages 35-59, female (...           NaN        NaN
# GNI per capita, PPP (current international $)       6.170000e+03        NaN
# Ratio of female to male labor force participati...  8.824970e+01        NaN
# Unemployment, female (% of female labor force) ...  1.900000e+00        NaN
# Ratio of female to male labor force participati...  8.768816e+01  87.745532
# Cause of death, by non-communicable diseases, a...           NaN        NaN
# GDP (current US$)                                   2.052762e+11        NaN
# Proportion of women in ministerial level positi...  4.200000e+00        NaN
# GDP growth (annual %)                               6.210812e+00        NaN
# Unemployment, male (% of male labor force) (mod...  2.200000e+00   2.200000
# Primary education, pupils (% female)                         NaN        NaN
# Proportion of seats held by women in national p...  2.670000e+01  26.700000
# GDP per capita (Current US$)                        2.214388e+03        NaN
# Unemployment, male (% of male labor force) (nat...  2.200000e+00        NaN
# Progression to secondary school, male (%)                    NaN        NaN
# GNI per capita, Atlas method (current US$)          2.100000e+03        NaN
# Progression to secondary school, female (%)                  NaN        NaN
# Cause of death, by injury, ages 35-59, male (% ...           NaN        NaN
# Primary education, teachers (% female)                       NaN        NaN
# Unemployment, youth female (% of female labor f...  6.600000e+00   6.500000
# Cause of death, by non-communicable diseases, a...           NaN        NaN
# Age at first marriage, male                                  NaN        NaN
#
#                                                     number of countries
# Indicator Name
# Adjusted net enrollment rate, primary, female (...                  223
# Employment in agriculture, male (% of male empl...                  232
# School enrollment, tertiary, female (% gross)                       226
# Employment in industry, female (% of female emp...                  232
# School enrollment, tertiary (gross), gender par...                  226
# Employment in industry, male (% of male employm...                  232
# School enrollment, secondary, male (% net)                          208
# Employment in services, female (% of female emp...                  232
# School enrollment, secondary, male (% gross)                        235
# Employment in services, male (% of male employm...                  232
# School enrollment, secondary, female (% net)                        208
# Employment to population ratio, 15+, female (%)...                  232
# School enrollment, secondary, female (% gross)                      235
# Employment to population ratio, 15+, female (%)...                  211
# School enrollment, secondary (gross), gender pa...                  235
# Employment to population ratio, 15+, male (%) (...                  232
# School enrollment, primary, male (% net)                            223
# Employment to population ratio, 15+, male (%) (...                  211
# School enrollment, primary, male (% gross)                          239
# Employment to population ratio, 15+, total (%) ...                  229
# School enrollment, primary, female (% net)                          223
# Employment to population ratio, ages 15-24, fem...                  232
# School enrollment, primary, female (% gross)                        239
# Employment to population ratio, ages 15-24, mal...                  232
# School enrollment, primary and secondary (gross...                  234
# Expected years of schooling, female                                 225
# School enrollment, tertiary, male (% gross)                         226
# Employment in agriculture, female (% of female ...                  232
# Secondary education, pupils (% female)                              244
# Employers, male (% of male employment) (modeled...                  232
# ...                                                                 ...
# Prevalence of anemia among women of reproductiv...                  234
# Urban population, male (% of total)                                 239
# Immunization, measles (% of children ages 12-23...                  238
# Pregnant women receiving prenatal care (%)                          202
# Cause of death, by communicable diseases, ages ...                  229
# Population, total                                                   263
# Prevalence of overweight, female (% of female a...                  234
# Cause of death, by non-communicable diseases, a...                  229
# Cause of death, by injury, ages 35-59, female (...                  229
# GNI per capita, PPP (current international $)                       236
# Ratio of female to male labor force participati...                  227
# Unemployment, female (% of female labor force) ...                  219
# Ratio of female to male labor force participati...                  233
# Cause of death, by non-communicable diseases, a...                  229
# GDP (current US$)                                                   256
# Proportion of women in ministerial level positi...                  239
# GDP growth (annual %)                                               253
# Unemployment, male (% of male labor force) (mod...                  232
# Primary education, pupils (% female)                                249
# Proportion of seats held by women in national p...                  240
# GDP per capita (Current US$)                                        256
# Unemployment, male (% of male labor force) (nat...                  219
# Progression to secondary school, male (%)                           212
# GNI per capita, Atlas method (current US$)                          246
# Progression to secondary school, female (%)                         212
# Cause of death, by injury, ages 35-59, male (% ...                  229
# Primary education, teachers (% female)                              241
# Unemployment, youth female (% of female labor f...                  232
# Cause of death, by non-communicable diseases, a...                  229
# Age at first marriage, male                                         198
#
# [1297 rows x 20 columns]
