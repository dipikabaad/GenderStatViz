# %%
import pandas as pd
import numpy as np
data = pd.read_csv('159 indicators for all the countries 2000 to 2016.csv')
data = data.drop(columns = {'Country Code', 'Indicator Code','Unnamed: 0'})
# data
def uni_gender(data):
    for index, row in data.iterrows():
        if ', male ' in row['Indicator Name']:
            data.set_value(index, 'Indicator Name', row['Indicator Name'].replace('male', ' '))            
            data.set_value(index, 'Gender', 'M')
        elif ', female ' in row['Indicator Name']:
            data.set_value(index, 'Indicator Name', row['Indicator Name'].replace('female', ' '))
            data.set_value(index, 'Gender', 'F')
        else:
            data.set_value(index, 'Gender', 'N')
    return data 
data = uni_gender(data)
# data
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# c:\python36\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# c:\python36\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# c:\python36\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# c:\python36\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
#                                             Country Name  \
# 0                                             Arab World
# 1                                 Caribbean small states
# 2                         Central Europe and the Baltics
# 3                             Early-demographic dividend
# 4                                    East Asia & Pacific
# 5            East Asia & Pacific (excluding high income)
# 6                       East Asia & Pacific (IDA & IBRD)
# 7                                              Euro area
# 8                                  Europe & Central Asia
# 9          Europe & Central Asia (excluding high income)
# 10                    Europe & Central Asia (IDA & IBRD)
# 11                                        European Union
# 12              Fragile and conflict affected situations
# 13                Heavily indebted poor countries (HIPC)
# 14                                           High income
# 15                                             IBRD only
# 16                                      IDA & IBRD total
# 17                                             IDA blend
# 18                                              IDA only
# 19                                             IDA total
# 20                             Late-demographic dividend
# 21                             Latin America & Caribbean
# 22     Latin America & Caribbean (excluding high income)
# 23                Latin America & Caribbean (IDA & IBRD)
# 24          Least developed countries: UN classification
# 25                                            Low income
# 26                                   Lower middle income
# 27                            Middle East & North Africa
# 28     Middle East & North Africa (excluding high inc...
# 29               Middle East & North Africa (IDA & IBRD)
# ...                                                  ...
# 36667                                           Suriname
# 36668                                          Swaziland
# 36669                                             Sweden
# 36670                                        Switzerland
# 36671                               Syrian Arab Republic
# 36672                                         Tajikistan
# 36673                                           Tanzania
# 36674                                           Thailand
# 36675                                        Timor-Leste
# 36676                                               Togo
# 36677                                              Tonga
# 36678                                Trinidad and Tobago
# 36679                                            Tunisia
# 36680                                             Turkey
# 36681                           Turks and Caicos Islands
# 36682                                             Tuvalu
# 36683                                             Uganda
# 36684                                            Ukraine
# 36685                               United Arab Emirates
# 36686                                     United Kingdom
# 36687                                      United States
# 36688                                            Uruguay
# 36689                                         Uzbekistan
# 36690                                            Vanuatu
# 36691                                      Venezuela, RB
# 36692                                            Vietnam
# 36693                                 West Bank and Gaza
# 36694                                        Yemen, Rep.
# 36695                                             Zambia
# 36696                                           Zimbabwe
#
#                                           Indicator Name       2000  \
# 0      Adjusted net enrollment rate, primary,   (% of...  73.275620
# 1      Adjusted net enrollment rate, primary,   (% of...  93.758873
# 2      Adjusted net enrollment rate, primary,   (% of...  95.659027
# 3      Adjusted net enrollment rate, primary,   (% of...  79.231354
# 4      Adjusted net enrollment rate, primary,   (% of...  94.710747
# 5      Adjusted net enrollment rate, primary,   (% of...  94.395027
# 6      Adjusted net enrollment rate, primary,   (% of...  94.373123
# 7      Adjusted net enrollment rate, primary,   (% of...  99.432869
# 8      Adjusted net enrollment rate, primary,   (% of...  96.254440
# 9      Adjusted net enrollment rate, primary,   (% of...  92.998520
# 10     Adjusted net enrollment rate, primary,   (% of...  93.369537
# 11     Adjusted net enrollment rate, primary,   (% of...  98.653687
# 12     Adjusted net enrollment rate, primary,   (% of...  52.773399
# 13     Adjusted net enrollment rate, primary,   (% of...  49.500938
# 14     Adjusted net enrollment rate, primary,   (% of...  97.119881
# 15     Adjusted net enrollment rate, primary,   (% of...  88.700851
# 16     Adjusted net enrollment rate, primary,   (% of...  80.257957
# 17     Adjusted net enrollment rate, primary,   (% of...  65.739182
# 18     Adjusted net enrollment rate, primary,   (% of...  57.804668
# 19     Adjusted net enrollment rate, primary,   (% of...  60.524239
# 20     Adjusted net enrollment rate, primary,   (% of...  95.150436
# 21     Adjusted net enrollment rate, primary,   (% of...  95.617821
# 22     Adjusted net enrollment rate, primary,   (% of...  95.640343
# 23     Adjusted net enrollment rate, primary,   (% of...  95.617477
# 24     Adjusted net enrollment rate, primary,   (% of...  56.250938
# 25     Adjusted net enrollment rate, primary,   (% of...  49.770721
# 26     Adjusted net enrollment rate, primary,   (% of...  76.246971
# 27     Adjusted net enrollment rate, primary,   (% of...  81.112289
# 28     Adjusted net enrollment rate, primary,   (% of...  81.578873
# 29     Adjusted net enrollment rate, primary,   (% of...  81.482643
# ...                                                  ...        ...
# 36667                        Age at first marriage, male  27.500000
# 36668                        Age at first marriage, male  30.100000
# 36669                        Age at first marriage, male        NaN
# 36670                        Age at first marriage, male  31.100000
# 36671                        Age at first marriage, male        NaN
# 36672                        Age at first marriage, male  24.100000
# 36673                        Age at first marriage, male        NaN
# 36674                        Age at first marriage, male  27.400000
# 36675                        Age at first marriage, male        NaN
# 36676                        Age at first marriage, male  28.200000
# 36677                        Age at first marriage, male        NaN
# 36678                        Age at first marriage, male  31.400000
# 36679                        Age at first marriage, male        NaN
# 36680                        Age at first marriage, male  26.100000
# 36681                        Age at first marriage, male        NaN
# 36682                        Age at first marriage, male        NaN
# 36683                        Age at first marriage, male        NaN
# 36684                        Age at first marriage, male        NaN
# 36685                        Age at first marriage, male        NaN
# 36686                        Age at first marriage, male        NaN
# 36687                        Age at first marriage, male  27.800000
# 36688                        Age at first marriage, male        NaN
# 36689                        Age at first marriage, male  24.100000
# 36690                        Age at first marriage, male        NaN
# 36691                        Age at first marriage, male  26.500000
# 36692                        Age at first marriage, male  26.000000
# 36693                        Age at first marriage, male  26.900000
# 36694                        Age at first marriage, male        NaN
# 36695                        Age at first marriage, male  25.400000
# 36696                        Age at first marriage, male        NaN
#
#             2001       2002       2003       2004       2005       2006  \
# 0      75.132980  76.641022  77.653580  78.485397  79.475769  79.608330
# 1      92.869598  92.252808  92.027557  93.611488  93.517563  93.021721
# 2      95.794853  95.854279  95.919563  95.728073  95.430458  95.440002
# 3      80.330177  81.186440  85.159439  86.620583  88.122643  89.345901
# 4      95.185143  97.313599  97.009399  97.015167  94.883293  94.409889
# 5      94.905861  97.202377  96.847282  96.861748  94.551651  94.023903
# 6      94.887177  97.203827  96.845329  96.860153  94.528511  93.995071
# 36681        NaN   ...          NaN        NaN        NaN        NaN
# 36682        NaN   ...          NaN        NaN        NaN        NaN
# 36683        NaN   ...          NaN  24.300000        NaN        NaN
# 36684  25.900000   ...          NaN        NaN  26.400000        NaN
# 36685        NaN   ...          NaN        NaN        NaN        NaN
# 36686        NaN   ...    33.300000  28.700000        NaN        NaN
# 36687        NaN   ...          NaN        NaN        NaN        NaN
# 36688        NaN   ...          NaN  26.500000        NaN        NaN
# 36689        NaN   ...          NaN        NaN        NaN        NaN
# 36690        NaN   ...          NaN        NaN        NaN        NaN
# 36691        NaN   ...          NaN        NaN        NaN        NaN
# 36692  26.600000   ...          NaN  26.400000        NaN        NaN
# 36693  26.600000   ...    27.800000        NaN        NaN        NaN
# 36694        NaN   ...          NaN        NaN        NaN  26.100000
# 36695  25.400000   ...    26.200000        NaN        NaN        NaN
# 36696        NaN   ...    25.500000        NaN        NaN        NaN
#
#             2014       2015  2016  2017  number of countries  Gender
# 0      83.820831        NaN   NaN   NaN                  223       F
# 1            NaN        NaN   NaN   NaN                  223       F
# 2      95.878433        NaN   NaN   NaN                  223       F
# 3      93.560097        NaN   NaN   NaN                  223       F
# 4      96.194817        NaN   NaN   NaN                  223       F
# 5      96.009018        NaN   NaN   NaN                  223       F
# 6      95.996513        NaN   NaN   NaN                  223       F
# 7      98.866081        NaN   NaN   NaN                  223       F
# 8      97.032494        NaN   NaN   NaN                  223       F
# 9      94.664413        NaN   NaN   NaN                  223       F
# 10     94.932793        NaN   NaN   NaN                  223       F
# 11     98.489517        NaN   NaN   NaN                  223       F
# 12     73.000732        NaN   NaN   NaN                  223       F
# 13     78.576210        NaN   NaN   NaN                  223       F
# 14     96.934563  97.357094   NaN   NaN                  223       F
# 15     96.173042        NaN   NaN   NaN                  223       F
# 16     89.555168        NaN   NaN   NaN                  223       F
# 17     72.112671        NaN   NaN   NaN                  223       F
# 18     81.196167        NaN   NaN   NaN                  223       F
# 19     78.367790        NaN   NaN   NaN                  223       F
# 20     96.443352        NaN   NaN   NaN                  223       F
# 21     94.198311        NaN   NaN   NaN                  223       F
# 22     94.225212        NaN   NaN   NaN                  223       F
# 23     94.236328        NaN   NaN   NaN                  223       F
# 24     80.452469        NaN   NaN   NaN                  223       F
# 25     78.729393  78.596001   NaN   NaN                  223       F
# 26     89.672188  89.440918   NaN   NaN                  223       F
# 27     93.214867        NaN   NaN   NaN                  223       F
# 28     92.868057        NaN   NaN   NaN                  223       F
# 29     92.866570        NaN   NaN   NaN                  223       F
# ...          ...        ...   ...   ...                  ...     ...
# 36667        NaN        NaN   NaN   NaN                  198       N
# 36668        NaN        NaN   NaN   NaN                  198       N
# 36669  33.100000        NaN   NaN   NaN                  198       N
# 36670  32.800000        NaN   NaN   NaN                  198       N
# 36671        NaN        NaN   NaN   NaN                  198       N
# 36672        NaN        NaN   NaN   NaN                  198       N
# 36673        NaN        NaN   NaN   NaN                  198       N
# 36674        NaN        NaN   NaN   NaN                  198       N
# 36675        NaN        NaN   NaN   NaN                  198       N
# 36676  27.600000        NaN   NaN   NaN                  198       N
# 36677        NaN        NaN   NaN   NaN                  198       N
# 36678        NaN        NaN   NaN   NaN                  198       N
# 36679        NaN        NaN   NaN   NaN                  198       N
# 36680        NaN        NaN   NaN   NaN                  198       N
# 36681        NaN        NaN   NaN   NaN                  198       N
# 36682        NaN        NaN   NaN   NaN                  198       N
# 36683        NaN        NaN   NaN   NaN                  198       N
# 36684        NaN        NaN   NaN   NaN                  198       N
# 36685        NaN        NaN   NaN   NaN                  198       N
# 36686        NaN        NaN   NaN   NaN                  198       N
# 36687        NaN        NaN   NaN   NaN                  198       N
# 36688        NaN        NaN   NaN   NaN                  198       N
# 36689        NaN        NaN   NaN   NaN                  198       N
# 36690        NaN        NaN   NaN   NaN                  198       N
# 36691        NaN        NaN   NaN   NaN                  198       N
# 36692        NaN        NaN   NaN   NaN                  198       N
# 36693        NaN        NaN   NaN   NaN                  198       N
# 36694        NaN        NaN   NaN   NaN                  198       N
# 36695  25.900000        NaN   NaN   NaN                  198       N
# 36696  25.200000        NaN   NaN   NaN                  198       N
#
# [36697 rows x 22 columns]

# %%
# data_region = data[(data['Country Name'] == 'East Asia & Pacific') | 
# (data['Country Name'] == 'Europe & Central Asia') | (data['Country Name'] == 'Latin America & Caribbean') | 
# (data['Country Name'] == 'Middle East & North Africa') | (data['Country Name'] == 'South Asia') | 
# (data['Country Name'] == 'Sub-Saharan Africa') | (data)['Country Name'] == 'North America']
# file_east_asia = pd.ExcelWriter('data region.xlsx')
# data_region.to_excel(file_east_asia, sheet_name =  'total')
# can be saved as xlsx, and to different sheets

# %%
# East_Asia_Pacific.to_excel(file_east_asia, sheet_name = 'East Asia & Pacific')

# file_east_asia.save()

# %%
# data_main_countries = data[(data['Country Name'] == 'Russian Federation')| (data['Country Name'] == 'Canada')| (data['Country Name'] == 'United States')| (data['Country Name'] == 'China')| (data['Country Name'] == 'Brazil')| (data['Country Name'] == 'Australia')| (data['Country Name'] == 'India')| (data['Country Name'] == 'Euro area')| (data['Country Name'] == 'United Kingdom')]
# data_main_countries.to_csv('data main countries.csv')

# %%
eap = data[(data['Country Name'] == 'East Asia & Pacific') | (data['Country Name'] == 'China') | 
           (data['Country Name'] == 'Japan') | (data['Country Name'] == 'Vietnam') |  
           (data['Country Name'] == 'Korea, Dem. People\'s Rep.') | (data['Country Name'] == 'Korea, Rep.') | 
           (data['Country Name'] == 'Philippines') | (data['Country Name'] == 'Australia') | 
           (data['Country Name'] == 'New Zealand') | (data['Country Name'] == 'Singapore')]
eap.sort_values(by = 'Country Name')
eap.to_csv('eap.csv')

# %%
eca = data[(data['Country Name'] == 'Europe & Central Asia') | (data['Country Name'] == 'Austria') | 
           (data['Country Name'] == 'Albania') | (data['Country Name'] == 'Belgium') |  
           (data['Country Name'] == 'Denmark') | (data['Country Name'] == 'Italy') | 
           (data['Country Name'] == 'Croatia') | (data['Country Name'] == 'France') | 
           (data['Country Name'] == 'Germany') | (data['Country Name'] == 'Greece')
#            (data['Country Name'] == 'Iceland') | (data['Country Name'] == 'Luxembourg') | 
#            (data['Country Name'] == 'Netherlands') | (data['Country Name'] == 'Sweden') | 
#            (data['Country Name'] == 'Switzerland') | (data['Country Name'] == 'Ukraine') | 
#            (data['Country Name'] == 'Turkey') | (data['Country Name'] == 'United Kingdom') |
#            (data['Country Name'] == 'Norway') | (data['Country Name'] == 'Finland') |  
#            (data['Country Name'] == 'Spain') | (data['Country Name'] == 'Poland') | 
#            (data['Country Name'] == 'Portugal') | (data['Country Name'] == 'Romania') | 
           (data['Country Name'] == 'Russian Federation') | (data['Country Name'] == 'Czech Republic')]
eca.sort_values(by = 'Country Name')
eca.to_csv('eca.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-db77da76a0e5> in <module>()
#      11 #            (data['Country Name'] == 'Spain') | (data['Country Name'] == 'Poland') |
#      12 #            (data['Country Name'] == 'Portugal') | (data['Country Name'] == 'Romania') |
# ---> 13            (data['Country Name'] == 'Russian Federation') | (data['Country Name'] == 'Czech Republic')]
#      14 eca.sort_values(by = 'Country Name')
#      15 eca.to_csv('eca.csv')
#
# TypeError: 'Series' object is not callable

# %%
lac = data[(data['Country Name'] == 'Latin America & Caribbean') | (data['Country Name'] == 'Argentina') | 
           (data['Country Name'] == 'Brazil') | (data['Country Name'] == 'Panama') |  
           (data['Country Name'] == 'Colombia') | (data['Country Name'] == 'Cuba') | 
           (data['Country Name'] == 'Haiti') | (data['Country Name'] == 'Jamaica') | 
           (data['Country Name'] == 'Mexico') | (data['Country Name'] == 'Chile')]
lac.sort_values(by = 'Country Name')
lac.to_csv('lac.csv')

# %%
mena = data[(data['Country Name'] == 'Middle East & North Africa') | (data['Country Name'] == 'United Arab Emirates') | 
           (data['Country Name'] == 'Egypt, Arab Rep.') | (data['Country Name'] == 'Iraq') |  
           (data['Country Name'] == 'Iran, Islamic Rep.') | (data['Country Name'] == 'Israel') | 
           (data['Country Name'] == 'Saudi Arabia') | (data['Country Name'] == 'Lebanon') | 
           (data['Country Name'] == 'Syrian Arab Republic') | (data['Country Name'] == 'Morocco')]
mena.sort_values(by = 'Country Name')
mena.to_csv('mena.csv')

# %%
sa = data[(data['Country Name'] == 'South Asia') | (data['Country Name'] == 'Afghanistan') | 
           (data['Country Name'] == 'Bangladesh') | (data['Country Name'] == 'Bhutan') |  
           (data['Country Name'] == 'India') | (data['Country Name'] == 'Nepal') | 
           (data['Country Name'] == 'Maldives') | (data['Country Name'] == 'Pakistan') | 
           (data['Country Name'] == 'Sri Lanka')]
sa.sort_values(by = 'Country Name')
sa.to_csv('sa.csv')

# %%
ssa = data[(data['Country Name'] == 'Sub-Saharan Africa') | (data['Country Name'] == 'Guinea-Bissau') | 
           (data['Country Name'] == 'Guinea') | (data['Country Name'] == 'Papua New Guinea') |  
           (data['Country Name'] == 'South Sudan') | (data['Country Name'] == 'Sudan') | 
           (data['Country Name'] == 'Equatorial Guinea') | (data['Country Name'] == 'Nigeria') | 
           (data['Country Name'] == 'South Africa') | (data['Country Name'] == 'Central African Republic')]
ssa.sort_values(by = 'Country Name')
ssa.to_csv('ssa.csv')

# %%
na = data[(data['Country Name'] == 'North America') | (data['Country Name'] == 'United States') | 
           (data['Country Name'] == 'Canada')]
na.sort_values(by = 'Country Name')
na.to_csv('na.csv')
